# %% [markdown]
# <a href="https://colab.research.google.com/github/jampi222/inteligencia-artificial/blob/main/Pandasf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas has two data structer
import pandas as pd

# %%
#series
tmp=pd.Series(data=[100,200,300,400],index=['Jose','Pedro','Joaquin','Mariana'])
#first form
print(tmp)
#second form
tmp
# Out:
# Jose       100
# Pedro      200
# Joaquin    300
# Mariana    400
# dtype: int64
# Jose       100
# Pedro      200
# Joaquin    300
# Mariana    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp['Pedro'])
# Out:
# 200

# %%
print(tmp[-3])
# Out:
# 200

# %%
tmp*2
# Out:
# Jose       200
# Pedro      400
# Joaquin    600
# Mariana    800
# dtype: int64

# %%
print(tmp[[1,2,3]])
print('- - — - -  - - - -')
tmp[[1,2,3]]
# Out:
# Pedro      200
# Joaquin    300
# Mariana    400
# dtype: int64
# - - — - -  - - - -
# Pedro      200
# Joaquin    300
# Mariana    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['Jose', 'Pedro', 'Joaquin', 'Mariana'], dtype='object')

# %%
miDiccionario = {"nombre": "John", "edad": 25, "ciudad": "New York"}

# %%
aux={'one':pd.Series([1,2,3],index=['manzana','pelota','reloj']),
     'two':pd.Series([10,20,30],index=['piña','sandia','banana']),}

# %%
print(aux)
# Out:
# {'one': manzana    1
# pelota     2
# reloj      3
# dtype: int64, 'two': piña      10
# sandia    20
# banana    30
# dtype: int64}

# %%
df=pd.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df.index
# Out:
# Index(['banana', 'manzana', 'pelota', 'piña', 'reloj', 'sandia'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']
df['four']=df['one']+df['two']
df['five']=df['one']-df['two']
df['six']=df['one']/df['two']
df
# Out:
#          one   two  three  four  five  six
# banana   NaN  30.0    NaN   NaN   NaN  NaN
# manzana  1.0   NaN    NaN   NaN   NaN  NaN
# pelota   2.0   NaN    NaN   NaN   NaN  NaN
# piña     NaN  10.0    NaN   NaN   NaN  NaN
# reloj    3.0   NaN    NaN   NaN   NaN  NaN
# sandia   NaN  20.0    NaN   NaN   NaN  NaN

# %%
df['filtro']=df['one']>=2
df
# Out:
#          one   two  three  four  five  six  filtro
# banana   NaN  30.0    NaN   NaN   NaN  NaN   False
# manzana  1.0   NaN    NaN   NaN   NaN  NaN   False
# pelota   2.0   NaN    NaN   NaN   NaN  NaN    True
# piña     NaN  10.0    NaN   NaN   NaN  NaN   False
# reloj    3.0   NaN    NaN   NaN   NaN  NaN    True
# sandia   NaN  20.0    NaN   NaN   NaN  NaN   False

# %%
del df['three']
df
# Out:
#          one   two  four  five  six  filtro
# banana   NaN  30.0   NaN   NaN  NaN   False
# manzana  1.0   NaN   NaN   NaN  NaN   False
# pelota   2.0   NaN   NaN   NaN  NaN    True
# piña     NaN  10.0   NaN   NaN  NaN   False
# reloj    3.0   NaN   NaN   NaN  NaN    True
# sandia   NaN  20.0   NaN   NaN  NaN   False

# %%
del df['filtro']
df
# Out:
#          one   two  four  five  six
# banana   NaN  30.0   NaN   NaN  NaN
# manzana  1.0   NaN   NaN   NaN  NaN
# pelota   2.0   NaN   NaN   NaN  NaN
# piña     NaN  10.0   NaN   NaN  NaN
# reloj    3.0   NaN   NaN   NaN  NaN
# sandia   NaN  20.0   NaN   NaN  NaN

# %%
df2=df.pop('four')

# %%
df
# Out:
#          one   two  five  six
# banana   NaN  30.0   NaN  NaN
# manzana  1.0   NaN   NaN  NaN
# pelota   2.0   NaN   NaN  NaN
# piña     NaN  10.0   NaN  NaN
# reloj    3.0   NaN   NaN  NaN
# sandia   NaN  20.0   NaN  NaN

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
tags.head(10)
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
ratings.head(25)
# Out:
#     userId  movieId  rating   timestamp
# 0        1        2     3.5  1112486027
# 1        1       29     3.5  1112484676
# 2        1       32     3.5  1112484819
# 3        1       47     3.5  1112484727
# 4        1       50     3.5  1112484580
# 5        1      112     3.5  1094785740
# 6        1      151     4.0  1094785734
# 7        1      223     4.0  1112485573
# 8        1      253     4.0  1112484940
# 9        1      260     4.0  1112484826
# 10       1      293     4.0  1112484703
# 11       1      296     4.0  1112484767
# 12       1      318     4.0  1112484798
# 13       1      337     3.5  1094785709
# 14       1      367     3.5  1112485980
# 15       1      541     4.0  1112484603
# 16       1      589     3.5  1112485557
# 17       1      593     3.5  1112484661
# 18       1      653     3.0  1094785691
# 19       1      919     3.5  1094785621
# 20       1      924     3.5  1094785598
# 21       1     1009     3.5  1112486013
# ...

# %%
ratings.tail(10)
# Out:
#          userId  movieId  rating   timestamp
# 1999990   13567    54004     3.5  1262994633
# 1999991   13567    58154     4.0  1262994642
# 1999992   13567    58559     5.0  1262994213
# 1999993   13567    59333     3.5  1262994526
# 1999994   13567    59369     4.0  1262764264
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418

# %%
#Video 2

# %%
movies='/content/setDatos/movies.csv'
ratings='/content/setDatos/ratings.csv'
tags='/content/setDatos/tags.csv'

# %%
movies=pd.read_csv(movies)
ratings=pd.read_csv(ratings)
tags=pd.read_csv(tags)

movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
movies.shape
# Out:
# (9742, 3)

# %%
tags.shape
# Out:
# (3683, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']

# %%
del tags['timestamp']

# %%
print(tags.head(5))
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %%
print(ratings.head(10))
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# 5       1       70     3.0
# 6       1      101     5.0
# 7       1      110     4.0
# 8       1      151     5.0
# 9       1      157     5.0

# %%
print(ratings.iloc[6])
# Out:
# userId       1.0
# movieId    101.0
# rating       5.0
# Name: 6, dtype: float64

# %%
print(ratings.iloc[[10,20,30,40,50]])
# Out:
#     userId  movieId  rating
# 10       1      163     5.0
# 20       1      356     4.0
# 30       1      552     4.0
# 40       1      733     4.0
# 50       1     1023     5.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
#minimo 1

print(ratings['rating'].min())
#minimo 2
print(ratings['rating'].max())
#minimo 3
print(ratings['rating'].mean())
#minimo 4
print(ratings['rating'].std())
# Out:
# 0.5
# 5.0
# 3.501556983616962
# 1.042529239060635

# %%
print(ratings.corr())
# Out:
#            userId   movieId    rating
# userId   1.000000  0.006773 -0.049348
# movieId  0.006773  1.000000 -0.004061
# rating  -0.049348 -0.004061  1.000000

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
filter=ratings['rating']>5
print(filter.any())
# Out:
# False

# %%
filter=ratings['rating']>0
print(filter.any())
# Out:
# True

# %%
aux=ratings[filter]
print(aux.shape)
print(aux.head(3))
# Out:
# (100836, 3)
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
ratings['rating'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100831    False
# 100832    False
# 100833    False
# 100834    False
# 100835    False
# Name: rating, Length: 100836, dtype: bool

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
"""ratings='/content/setDatos/ratings.csv'
ratings=js.read_csv(ratings)"""


ratings.hist(column='rating',figsize=[10,7])
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
movies='/content/setDatos/movies.csv'
ratings='/content/setDatos/ratings.csv'
tags='/content/setDatos/tags.csv'
movies=pd.read_csv(movies)
ratings=pd.read_csv(ratings)
tags=pd.read_csv(tags)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.hist(column='timestamp',figsize=[10,7])
# Out:
# array([[<Axes: title={'center': 'timestamp'}>]], dtype=object)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
is_animation=movies['genres'].str.contains('Animation')

# %%
newMovies=movies[is_animation]

# %%
newMovies.head(10)
# Out:
#      movieId                                   title  \
# 0          1                        Toy Story (1995)
# 12        13                            Balto (1995)
# 44        48                       Pocahontas (1995)
# 205      239                   Goofy Movie, A (1995)
# 272      313               Swan Princess, The (1994)
# 322      364                   Lion King, The (1994)
# 483      551  Nightmare Before Christmas, The (1993)
# 488      558                  Pagemaster, The (1994)
# 506      588                          Aladdin (1992)
# 511      594  Snow White and the Seven Dwarfs (1937)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 44          Animation|Children|Drama|Musical|Romance
# 205                Animation|Children|Comedy|Romance
# 272                               Animation|Children
# 322  Adventure|Animation|Children|Drama|Musical|IMAX
# ...

# %%
tags.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags['informationDateTime']=pd.to_datetime(tags['timestamp'],unit='s')

# %%
tags.head(10)
# Out:
#    userId  movieId                tag   timestamp informationDateTime
# 0       2    60756              funny  1445714994 2015-10-24 19:29:54
# 1       2    60756    Highly quotable  1445714996 2015-10-24 19:29:56
# 2       2    60756       will ferrell  1445714992 2015-10-24 19:29:52
# 3       2    89774       Boxing story  1445715207 2015-10-24 19:33:27
# 4       2    89774                MMA  1445715200 2015-10-24 19:33:20
# 5       2    89774          Tom Hardy  1445715205 2015-10-24 19:33:25
# 6       2   106782              drugs  1445715054 2015-10-24 19:30:54
# 7       2   106782  Leonardo DiCaprio  1445715051 2015-10-24 19:30:51
# 8       2   106782    Martin Scorsese  1445715056 2015-10-24 19:30:56
# 9       7    48516       way too long  1169687325 2007-01-25 01:08:45
