# %% [markdown]
# <a href="https://colab.research.google.com/github/jampi222/inteligencia-artificial/blob/main/22_11_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movies ='/content/setData/movies.csv'
rating ='/content/setData/ratings.csv'
tags= '/content/setData/tags.csv'

# %%
movies=pd.read_csv(movies)
ratings=pd.read_csv(rating)
tags=pd.read_csv(tags)
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating    timestamp
# 0       1        1     4.0  964982703.0
# 1       1        3     4.0  964981247.0
# 2       1        6     4.0  964982224.0

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
ratings.shape
# Out:
# (85271, 4)

# %%
movies.shape
# Out:
# (9742, 3)

# %%
tags.shape
# Out:
# (3683, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings ['timestamp']
del tags['timestamp']

# %%
tags.head(5)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %%
ratings.tail(5)
# Out:
#        userId  movieId  rating
# 85266     554     2243     3.0
# 85267     554     2282     5.0
# 85268     554     2324     5.0
# 85269     554     2396     5.0
# 85270     554      249     NaN

# %%
ratings.iloc[6]
# Out:
# userId       1.0
# movieId    101.0
# rating       5.0
# Name: 6, dtype: float64

# %%
print(ratings.iloc[[30,40,50]])
# Out:
#     userId  movieId  rating
# 30       1      552     4.0
# 40       1      733     4.0
# 50       1     1023     5.0

# %%
ratings.describe()
# Out:
#              userId        movieId        rating
# count  85271.000000   85271.000000  85270.000000
# mean     277.872641   19258.870847      3.523496
# std      155.875583   35277.240853      1.040897
# min        1.000000       1.000000      0.500000
# 25%      140.000000    1196.000000      3.000000
# 50%      288.000000    2987.000000      3.500000
# 75%      414.000000    7892.500000      4.000000
# max      554.000000  193609.000000      5.000000

# %%
ratings.shape
# Out:
# (85271, 3)

# %%
print(ratings['rating'].min())
# Out:
# 0.5

# %%
print(ratings['rating'].max())
# Out:
# 5.0

# %%
print(ratings['rating'].mean())
# Out:
# 3.5234959540283803

# %%
print(ratings['rating'].std())
# Out:
# 1.0408973681906935

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.000538 -0.025155
# movieId  0.000538  1.000000  0.004469
# rating  -0.025155  0.004469  1.000000

# %%
filtro=ratings['rating']>5

# %%
filtro.any()
# Out:
# False

# %%
mask=ratings['rating']>3

# %%
print(mask.any())
# Out:
# True

# %%
aux=ratings[mask]
print(aux.shape)
print(aux.head(3))
# Out:
# (53081, 3)
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
ratings.shape
# Out:
# (85271, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating      True
# dtype: bool

# %%
ratings.hist(column='rating',figsize=(10,7))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
is_animation=movies['genres'].str.contains('Animation')

# %%
newMovies=movies[is_animation]

# %%
newMovies.head(10)
# Out:
#      movieId                                   title  \
# 0          1                        Toy Story (1995)
# 12        13                            Balto (1995)
# 44        48                       Pocahontas (1995)
# 205      239                   Goofy Movie, A (1995)
# 272      313               Swan Princess, The (1994)
# 322      364                   Lion King, The (1994)
# 483      551  Nightmare Before Christmas, The (1993)
# 488      558                  Pagemaster, The (1994)
# 506      588                          Aladdin (1992)
# 511      594  Snow White and the Seven Dwarfs (1937)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 44          Animation|Children|Drama|Musical|Romance
# 205                Animation|Children|Comedy|Romance
# 272                               Animation|Children
# 322  Adventure|Animation|Children|Drama|Musical|IMAX
# ...

# %%
tags ='/content/setData/ratings.csv'
tags=pd.read_csv(tags)

# %%
tags['informationDateTime']=pd.to_datetime(tags['timestamp'],unit='s')

# %%
tags.head(10)
# Out:
#    userId  movieId  rating    timestamp informationDateTime
# 0       1        1     4.0  964982703.0 2000-07-30 18:45:03
# 1       1        3     4.0  964981247.0 2000-07-30 18:20:47
# 2       1        6     4.0  964982224.0 2000-07-30 18:37:04
# 3       1       47     5.0  964983815.0 2000-07-30 19:03:35
# 4       1       50     5.0  964982931.0 2000-07-30 18:48:51
# 5       1       70     3.0  964982400.0 2000-07-30 18:40:00
# 6       1      101     5.0  964980868.0 2000-07-30 18:14:28
# 7       1      110     4.0  964982176.0 2000-07-30 18:36:16
# 8       1      151     5.0  964984041.0 2000-07-30 19:07:21
# 9       1      157     5.0  964984100.0 2000-07-30 19:08:20
